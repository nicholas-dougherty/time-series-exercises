# %% [markdown]
# # Seaborn Warmup Exercise

# %%
import seaborn as sns

df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Use seaborn to create the following visualizations:
#
# 1. Make a barplot of the average horsepower by origin. Add the keyword argument `ci=None`. What does this change?
# 1. Make a scatterplot of displacement vs horsepower. Add the keyword argument `hue='weight'`. What does this change? Add the keyword argument `palette='Greens'`. What does this change?
# 1. Make a scatterplot of displacement vs mpg. Add the keyword argument `hue='cylinders'`. What does this change? Add the line of code below in a seperate cell, run it, and then create your scatterplot again. What does this change?
#
#     ```python
#     df.cylinders = df.cylinders.astype('category')
#     ```

# %%
#typing none after the figure gets rid of the annoying output
sns.barplot(data=df, x= 'origin', y='horsepower', ci=None)
None
#typing none after the figure gets rid of the annoying output
#sns.barplot(data=df, x= 'horsepower', y='origin', ci=None)

# %% [markdown]
# Make a scatterplot of displacement vs horsepower. Add the keyword argument hue='weight'. What does this change? Add the keyword argument palette='Greens'. What does this change?

# %%
sns.scatterplot(data=df, x='displacement', y='horsepower', hue='weight', palette='Greens')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# Make a scatterplot of displacement vs mpg. Add the keyword argument hue='cylinders'. What does this change? Add the line of code below in a seperate cell, run it, and then create your scatterplot again. What does this change?
#
# df.cylinders = df.cylinders.astype('category')

# %%
sns.scatterplot(data=df, x='displacement', y='mpg', hue='cylinders')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
df.cylinders = df.cylinders.astype('category')
sns.scatterplot(data=df, x='displacement', y='mpg', hue='cylinders')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 7))

sns.scatterplot(data=df, y ='mpg', x= 'displacement', ax=ax1)
sns.scatterplot(data=df, y='mpg', x='weight', ax=ax2)
                
                
ax1.set(title='Displacement Vs Mpg')
ax2.set(title='Weight vs MPG')
fig.suptitle('Cars MPG Visualizations')
# Out:
# Text(0.5, 0.98, 'Cars MPG Visualizations')
